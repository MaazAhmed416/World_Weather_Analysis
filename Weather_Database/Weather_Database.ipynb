# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=100, size=2000)
lngs = np.random.uniform(low=-90, high=100, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | velventos
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | illoqqortoormiut
# 'coord'
# Processing Record 5 of Set 1 | sibiti
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | belushya guba
# 'coord'
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | vestmanna
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | mizdah
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | san pedro
# Processing Record 16 of Set 1 | dapaong
# Processing Record 17 of Set 1 | samana
# Processing Record 18 of Set 1 | nanortalik
# Processing Record 19 of Set 1 | afmadu
# 'coord'
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | gat
# Processing Record 22 of Set 1 | harper
# Processing Record 23 of Set 1 | paamiut
# Processing Record 24 of Set 1 | barentsburg
# 'coord'
# Processing Record 25 of Set 1 | wicklow
# Processing Record 26 of Set 1 | berlevag
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | atasu
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | luderitz
# Processing Record 32 of Set 1 | buckingham
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | maniitsoq
# Processing Record 35 of Set 1 | kumluca
# Processing Record 36 of Set 1 | minsk
# Processing Record 37 of Set 1 | umzimvubu
# 'coord'
# Processing Record 38 of Set 1 | cap malheureux
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | tsurib
# Processing Record 43 of Set 1 | codrington
# Processing Record 44 of Set 1 | brae
# Processing Record 45 of Set 1 | general roca
# Processing Record 46 of Set 1 | marquette
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | oxapampa
# Processing Record 2 of Set 2 | taolanaro
# 'coord'
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | kasra
# 'coord'
# Processing Record 5 of Set 2 | poitiers
# Processing Record 6 of Set 2 | banda aceh
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | tumannyy
# 'coord'
# Processing Record 9 of Set 2 | senno
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | laguna
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | yar-sale
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | necochea
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | bayan
# Processing Record 19 of Set 2 | jibuti
# Processing Record 20 of Set 2 | bindura
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | rocha
# Processing Record 24 of Set 2 | boguchany
# Processing Record 25 of Set 2 | halvad
# Processing Record 26 of Set 2 | namibe
# Processing Record 27 of Set 2 | norrtalje
# Processing Record 28 of Set 2 | sechura
# Processing Record 29 of Set 2 | kavaratti
# Processing Record 30 of Set 2 | westport
# Processing Record 31 of Set 2 | villarrica
# Processing Record 32 of Set 2 | natal
# Processing Record 33 of Set 2 | attawapiskat
# 'coord'
# Processing Record 34 of Set 2 | maceio
# Processing Record 35 of Set 2 | boleslawiec
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | kansanshi
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | hamilton
# Processing Record 40 of Set 2 | lubao
# Processing Record 41 of Set 2 | luanda
# Processing Record 42 of Set 2 | hami
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | atar
# Processing Record 45 of Set 2 | abay
# Processing Record 46 of Set 2 | muros
# Processing Record 47 of Set 2 | cajamarca
# Processing Record 48 of Set 2 | kibre mengist
# Processing Record 49 of Set 2 | hit
# Processing Record 50 of Set 2 | vilhena
# Processing Record 1 of Set 3 | taoudenni
# Processing Record 2 of Set 3 | lugovoy
# Processing Record 3 of Set 3 | marcona
# 'coord'
# Processing Record 4 of Set 3 | oistins
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | owando
# Processing Record 7 of Set 3 | alberton
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | itaberaba
# Processing Record 10 of Set 3 | chapleau
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 | comodoro rivadavia
# Processing Record 13 of Set 3 | mehamn
# Processing Record 14 of Set 3 | coquimbo
# Processing Record 15 of Set 3 | quelimane
# Processing Record 16 of Set 3 | dingle
# Processing Record 17 of Set 3 | tsabong
# Processing Record 18 of Set 3 | burica
# 'coord'
# Processing Record 19 of Set 3 | bubaque
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | veraval
# Processing Record 22 of Set 3 | taltal
# Processing Record 23 of Set 3 | soyo
# Processing Record 24 of Set 3 | tessalit
# Processing Record 25 of Set 3 | bodrum
# Processing Record 26 of Set 3 | dale
# Processing Record 27 of Set 3 | sibolga
# Processing Record 28 of Set 3 | morros
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | najran
# Processing Record 31 of Set 3 | tsienyane
# 'coord'
# Processing Record 32 of Set 3 | bilma
# Processing Record 33 of Set 3 | tefe
# Processing Record 34 of Set 3 | buraydah
# Processing Record 35 of Set 3 | tabuk
# Processing Record 36 of Set 3 | watsa
# Processing Record 37 of Set 3 | griffin
# Processing Record 38 of Set 3 | los llanos de aridane
# Processing Record 39 of Set 3 | hambantota
# Processing Record 40 of Set 3 | manjakandriana
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | mehran
# Processing Record 43 of Set 3 | jiddah
# 'coord'
# Processing Record 44 of Set 3 | dutlwe
# Processing Record 45 of Set 3 | trairi
# Processing Record 46 of Set 3 | daoukro
# Processing Record 47 of Set 3 | bardsir
# Processing Record 48 of Set 3 | leshukonskoye
# Processing Record 49 of Set 3 | salalah
# Processing Record 50 of Set 3 | cayenne
# Processing Record 1 of Set 4 | rio pardo
# Processing Record 2 of Set 4 | san cristobal
# Processing Record 3 of Set 4 | camacha
# Processing Record 4 of Set 4 | safaga
# Processing Record 5 of Set 4 | yuzhno-yeniseyskiy
# 'coord'
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | zarnovica
# Processing Record 9 of Set 4 | abu dhabi
# Processing Record 10 of Set 4 | toftir
# 'coord'
# Processing Record 11 of Set 4 | road town
# Processing Record 12 of Set 4 | jamnah
# 'coord'
# Processing Record 13 of Set 4 | hualmay
# Processing Record 14 of Set 4 | itarema
# Processing Record 15 of Set 4 | dali
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | kabare
# Processing Record 18 of Set 4 | narsaq
# Processing Record 19 of Set 4 | baboua
# 'coord'
# Processing Record 20 of Set 4 | yirol
# 'coord'
# Processing Record 21 of Set 4 | cartagena
# Processing Record 22 of Set 4 | moen
# Processing Record 23 of Set 4 | kasane
# Processing Record 24 of Set 4 | la palma
# Processing Record 25 of Set 4 | jabinyanah
# Processing Record 26 of Set 4 | chapais
# Processing Record 27 of Set 4 | kalevala
# Processing Record 28 of Set 4 | qaqortoq
# Processing Record 29 of Set 4 | bella vista
# Processing Record 30 of Set 4 | sarmanovo
# Processing Record 31 of Set 4 | coihaique
# Processing Record 32 of Set 4 | deep river
# Processing Record 33 of Set 4 | bainbridge
# Processing Record 34 of Set 4 | port-gentil
# Processing Record 35 of Set 4 | nivala
# Processing Record 36 of Set 4 | moffat
# Processing Record 37 of Set 4 | hobyo
# Processing Record 38 of Set 4 | tsarychanka
# Processing Record 39 of Set 4 | pangnirtung
# Processing Record 40 of Set 4 | astana
# Processing Record 41 of Set 4 | grand river south east
# 'coord'
# Processing Record 42 of Set 4 | mashhad
# Processing Record 43 of Set 4 | susangerd
# Processing Record 44 of Set 4 | marawi
# Processing Record 45 of Set 4 | goundam
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | chadiza
# Processing Record 48 of Set 4 | blagoyevo
# Processing Record 49 of Set 4 | bafq
# Processing Record 50 of Set 4 | sao miguel do araguaia
# Processing Record 1 of Set 5 | dwarka
# Processing Record 2 of Set 5 | pompeu
# Processing Record 3 of Set 5 | iracoubo
# Processing Record 4 of Set 5 | nioro
# Processing Record 5 of Set 5 | marrakesh
# Processing Record 6 of Set 5 | miedzyrzec podlaski
# Processing Record 7 of Set 5 | iquitos
# Processing Record 8 of Set 5 | mumford
# Processing Record 9 of Set 5 | zheleznodorozhnyy
# Processing Record 10 of Set 5 | omboue
# Processing Record 11 of Set 5 | massakory
# Processing Record 12 of Set 5 | viligili
# 'coord'
# Processing Record 13 of Set 5 | boa vista
# Processing Record 14 of Set 5 | havoysund
# Processing Record 15 of Set 5 | samagaltay
# Processing Record 16 of Set 5 | sao filipe
# Processing Record 17 of Set 5 | aginskoye
# Processing Record 18 of Set 5 | nizhnedevitsk
# Processing Record 19 of Set 5 | nsanje
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | torbay
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | helsinki
# Processing Record 24 of Set 5 | bahia de caraquez
# Processing Record 25 of Set 5 | amderma
# 'coord'
# Processing Record 26 of Set 5 | eirunepe
# Processing Record 27 of Set 5 | vittoria
# Processing Record 28 of Set 5 | balkanabat
# Processing Record 29 of Set 5 | owosso
# Processing Record 30 of Set 5 | yermekeyevo
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | paraguacu
# Processing Record 33 of Set 5 | kita
# Processing Record 34 of Set 5 | valdivia
# Processing Record 35 of Set 5 | svetlogorsk
# Processing Record 36 of Set 5 | ayagoz
# Processing Record 37 of Set 5 | aksarka
# Processing Record 38 of Set 5 | farim
# Processing Record 39 of Set 5 | luena
# Processing Record 40 of Set 5 | moose factory
# Processing Record 41 of Set 5 | korla
# Processing Record 42 of Set 5 | store heddinge
# Processing Record 43 of Set 5 | tukrah
# Processing Record 44 of Set 5 | jardim
# Processing Record 45 of Set 5 | mantua
# Processing Record 46 of Set 5 | mandsaur
# Processing Record 47 of Set 5 | danielskuil
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | opuwo
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | sept-iles
# Processing Record 2 of Set 6 | cockburn town
# Processing Record 3 of Set 6 | yining
# Processing Record 4 of Set 6 | muisne
# Processing Record 5 of Set 6 | shakhtinsk
# Processing Record 6 of Set 6 | lagoa
# Processing Record 7 of Set 6 | carutapera
# Processing Record 8 of Set 6 | gazojak
# Processing Record 9 of Set 6 | fez
# Processing Record 10 of Set 6 | matara
# Processing Record 11 of Set 6 | vila velha
# Processing Record 12 of Set 6 | iqaluit
# Processing Record 13 of Set 6 | schluchtern
# Processing Record 14 of Set 6 | viransehir
# Processing Record 15 of Set 6 | tasbuget
# 'coord'
# Processing Record 16 of Set 6 | novo aripuana
# Processing Record 17 of Set 6 | fria
# Processing Record 18 of Set 6 | puerto leguizamo
# Processing Record 19 of Set 6 | camara de lobos
# Processing Record 20 of Set 6 | bahir dar
# Processing Record 21 of Set 6 | dom pedro
# Processing Record 22 of Set 6 | sao geraldo do araguaia
# Processing Record 23 of Set 6 | isiro
# Processing Record 24 of Set 6 | krasnoselkup
# Processing Record 25 of Set 6 | sao joao da barra
# Processing Record 26 of Set 6 | monrovia
# Processing Record 27 of Set 6 | warqla
# 'coord'
# Processing Record 28 of Set 6 | sao francisco
# Processing Record 29 of Set 6 | pirot
# Processing Record 30 of Set 6 | cidreira
# Processing Record 31 of Set 6 | ambodifototra
# 'coord'
# Processing Record 32 of Set 6 | kirya
# Processing Record 33 of Set 6 | conceicao da barra
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | kulhudhuffushi
# Processing Record 36 of Set 6 | zemio
# Processing Record 37 of Set 6 | mamallapuram
# Processing Record 38 of Set 6 | monte alegre
# Processing Record 39 of Set 6 | raga
# Processing Record 40 of Set 6 | saint-georges
# Processing Record 41 of Set 6 | tsihombe
# 'coord'
# Processing Record 42 of Set 6 | henties bay
# Processing Record 43 of Set 6 | barpali
# Processing Record 44 of Set 6 | kilindoni
# Processing Record 45 of Set 6 | labuhan
# Processing Record 46 of Set 6 | hamina
# Processing Record 47 of Set 6 | wiarton
# Processing Record 48 of Set 6 | marystown
# Processing Record 49 of Set 6 | amalapuram
# Processing Record 50 of Set 6 | areosa
# Processing Record 1 of Set 7 | kavkazskiy
# Processing Record 2 of Set 7 | mahibadhoo
# Processing Record 3 of Set 7 | yopal
# Processing Record 4 of Set 7 | souillac
# Processing Record 5 of Set 7 | aviles
# Processing Record 6 of Set 7 | muzhi
# Processing Record 7 of Set 7 | muli
# Processing Record 8 of Set 7 | kisangani
# Processing Record 9 of Set 7 | reitz
# Processing Record 10 of Set 7 | nushki
# Processing Record 11 of Set 7 | ambilobe
# Processing Record 12 of Set 7 | arrecife
# Processing Record 13 of Set 7 | danville
# Processing Record 14 of Set 7 | leninskoye
# Processing Record 15 of Set 7 | gedo
# Processing Record 16 of Set 7 | kalmunai
# Processing Record 17 of Set 7 | pahalgam
# Processing Record 18 of Set 7 | machinga
# Processing Record 19 of Set 7 | marondera
# Processing Record 20 of Set 7 | salgueiro
# Processing Record 21 of Set 7 | takoradi
# Processing Record 22 of Set 7 | letlhakane
# Processing Record 23 of Set 7 | hereford
# Processing Record 24 of Set 7 | mbouda
# Processing Record 25 of Set 7 | ostrovnoy
# Processing Record 26 of Set 7 | bandar-e torkaman
# 'coord'
# Processing Record 27 of Set 7 | campo grande
# Processing Record 28 of Set 7 | vestmannaeyjar
# Processing Record 29 of Set 7 | requena
# Processing Record 30 of Set 7 | bandarbeyla
# Processing Record 31 of Set 7 | mingaora
# Processing Record 32 of Set 7 | cucer
# 'coord'
# Processing Record 33 of Set 7 | havelock
# Processing Record 34 of Set 7 | kamarion
# Processing Record 35 of Set 7 | imeni babushkina
# Processing Record 36 of Set 7 | kamenskiy
# Processing Record 37 of Set 7 | bud
# Processing Record 38 of Set 7 | port blair
# Processing Record 39 of Set 7 | kungalv
# Processing Record 40 of Set 7 | priiskovyy
# Processing Record 41 of Set 7 | bathsheba
# Processing Record 42 of Set 7 | salisbury
# Processing Record 43 of Set 7 | saint-augustin
# Processing Record 44 of Set 7 | abnub
# Processing Record 45 of Set 7 | horodnya
# Processing Record 46 of Set 7 | orahovac
# Processing Record 47 of Set 7 | zhangye
# Processing Record 48 of Set 7 | praia da vitoria
# Processing Record 49 of Set 7 | trincomalee
# Processing Record 50 of Set 7 | el paso
# Processing Record 1 of Set 8 | vuktyl
# Processing Record 2 of Set 8 | riviere-du-loup
# Processing Record 3 of Set 8 | dibulla
# Processing Record 4 of Set 8 | huanta
# Processing Record 5 of Set 8 | aripuana
# Processing Record 6 of Set 8 | rock sound
# Processing Record 7 of Set 8 | port-cartier
# Processing Record 8 of Set 8 | tazovskiy
# Processing Record 9 of Set 8 | basoko
# Processing Record 10 of Set 8 | arroio grande
# Processing Record 11 of Set 8 | yugo-kamskiy
# Processing Record 12 of Set 8 | jalu
# Processing Record 13 of Set 8 | jiayuguan
# Processing Record 14 of Set 8 | zabid
# Processing Record 15 of Set 8 | hunza
# 'coord'
# Processing Record 16 of Set 8 | umm lajj
# Processing Record 17 of Set 8 | tereze
# Processing Record 18 of Set 8 | ulaangom
# Processing Record 19 of Set 8 | kutum
# Processing Record 20 of Set 8 | pietroasa
# Processing Record 21 of Set 8 | nizwa
# Processing Record 22 of Set 8 | matay
# Processing Record 23 of Set 8 | chala
# Processing Record 24 of Set 8 | magway
# Processing Record 25 of Set 8 | sao miguel do tapuio
# Processing Record 26 of Set 8 | ust-tsilma
# Processing Record 27 of Set 8 | tame
# Processing Record 28 of Set 8 | porto santo
# Processing Record 29 of Set 8 | ardistan
# 'coord'
# Processing Record 30 of Set 8 | parauna
# Processing Record 31 of Set 8 | berck
# Processing Record 32 of Set 8 | buqayq
# 'coord'
# Processing Record 33 of Set 8 | mega
# Processing Record 34 of Set 8 | koungheul
# Processing Record 35 of Set 8 | puerto madryn
# Processing Record 36 of Set 8 | salmas
# Processing Record 37 of Set 8 | kemijarvi
# Processing Record 38 of Set 8 | les cayes
# Processing Record 39 of Set 8 | tastur
# Processing Record 40 of Set 8 | damara
# Processing Record 41 of Set 8 | bodden town
# Processing Record 42 of Set 8 | bagan
# Processing Record 43 of Set 8 | ashford
# Processing Record 44 of Set 8 | atocha
# Processing Record 45 of Set 8 | tuggurt
# 'coord'
# Processing Record 46 of Set 8 | faya
# Processing Record 47 of Set 8 | nagua
# Processing Record 48 of Set 8 | spring hill
# Processing Record 49 of Set 8 | barcelos
# Processing Record 50 of Set 8 | japura
# Processing Record 1 of Set 9 | nouadhibou
# Processing Record 2 of Set 9 | skalistyy
# 'coord'
# Processing Record 3 of Set 9 | muscat
# Processing Record 4 of Set 9 | cerbal
# 'coord'
# Processing Record 5 of Set 9 | walvis bay
# Processing Record 6 of Set 9 | oranjemund
# Processing Record 7 of Set 9 | pontes e lacerda
# Processing Record 8 of Set 9 | san jose
# Processing Record 9 of Set 9 | gander
# Processing Record 10 of Set 9 | neustadt
# Processing Record 11 of Set 9 | jizan
# Processing Record 12 of Set 9 | honavar
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | chicama
# Processing Record 15 of Set 9 | mugur-aksy
# Processing Record 16 of Set 9 | buchlovice
# Processing Record 17 of Set 9 | illapel
# Processing Record 18 of Set 9 | guider
# Processing Record 19 of Set 9 | polis
# Processing Record 20 of Set 9 | nacala
# Processing Record 21 of Set 9 | huarmey
# Processing Record 22 of Set 9 | sinnamary
# Processing Record 23 of Set 9 | pisco
# Processing Record 24 of Set 9 | puerto varas
# Processing Record 25 of Set 9 | chimala
# Processing Record 26 of Set 9 | ibicui
# Processing Record 27 of Set 9 | cheveresu mare
# Processing Record 28 of Set 9 | rapar
# Processing Record 29 of Set 9 | tshikapa
# Processing Record 30 of Set 9 | tocopilla
# Processing Record 31 of Set 9 | nova olimpia
# Processing Record 32 of Set 9 | olafsvik
# Processing Record 33 of Set 9 | bereda
# Processing Record 34 of Set 9 | saint simons
# Processing Record 35 of Set 9 | arlit
# Processing Record 36 of Set 9 | rawah
# Processing Record 37 of Set 9 | tiznit
# Processing Record 38 of Set 9 | akdepe
# Processing Record 39 of Set 9 | nara
# Processing Record 40 of Set 9 | porto de moz
# Processing Record 41 of Set 9 | hauge
# Processing Record 42 of Set 9 | dingli
# Processing Record 43 of Set 9 | batsfjord
# Processing Record 44 of Set 9 | aflu
# 'coord'
# Processing Record 45 of Set 9 | ginda
# Processing Record 46 of Set 9 | kuznechnoye
# Processing Record 47 of Set 9 | filadelfia
# Processing Record 48 of Set 9 | espanola
# Processing Record 49 of Set 9 | cabedelo
# Processing Record 50 of Set 9 | santa barbara
# Processing Record 1 of Set 10 | marzuq
# Processing Record 2 of Set 10 | parabel
# Processing Record 3 of Set 10 | teruel
# Processing Record 4 of Set 10 | arona
# Processing Record 5 of Set 10 | alencon
# Processing Record 6 of Set 10 | yenangyaung
# Processing Record 7 of Set 10 | santa cruz
# Processing Record 8 of Set 10 | grindavik
# Processing Record 9 of Set 10 | kachiry
# Processing Record 10 of Set 10 | nagram
# Processing Record 11 of Set 10 | camacupa
# Processing Record 12 of Set 10 | santa maria
# Processing Record 13 of Set 10 | kudahuvadhoo
# Processing Record 14 of Set 10 | ubinskoye
# Processing Record 15 of Set 10 | khorramshahr
# Processing Record 16 of Set 10 | kopavogur
# Processing Record 17 of Set 10 | riedlingen
# Processing Record 18 of Set 10 | qasigiannguit
# Processing Record 19 of Set 10 | nuuk
# Processing Record 20 of Set 10 | oudtshoorn
# Processing Record 21 of Set 10 | verkhnyaya inta
# Processing Record 22 of Set 10 | dunfermline
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | gamboma
# Processing Record 25 of Set 10 | kashi
# Processing Record 26 of Set 10 | zvishavane
# Processing Record 27 of Set 10 | chabahar
# Processing Record 28 of Set 10 | livingston
# Processing Record 29 of Set 10 | wajir
# Processing Record 30 of Set 10 | yanam
# Processing Record 31 of Set 10 | san carlos del zulia
# Processing Record 32 of Set 10 | sahrak
# 'coord'
# Processing Record 33 of Set 10 | mikhaylovka
# Processing Record 34 of Set 10 | issa
# Processing Record 35 of Set 10 | ozinki
# Processing Record 36 of Set 10 | plettenberg bay
# Processing Record 37 of Set 10 | havre-saint-pierre
# Processing Record 38 of Set 10 | kaniama
# Processing Record 39 of Set 10 | honningsvag
# Processing Record 40 of Set 10 | quilmana
# Processing Record 41 of Set 10 | babanusah
# 'coord'
# Processing Record 42 of Set 10 | alexandria
# Processing Record 43 of Set 10 | rosetta
# Processing Record 44 of Set 10 | pipri
# Processing Record 45 of Set 10 | novovelichkovskaya
# Processing Record 46 of Set 10 | bjornevatn
# Processing Record 47 of Set 10 | corbu
# Processing Record 48 of Set 10 | porto novo
# Processing Record 49 of Set 10 | alamor
# Processing Record 50 of Set 10 | segou
# Processing Record 1 of Set 11 | vila do maio
# Processing Record 2 of Set 11 | sambava
# Processing Record 3 of Set 11 | bhuban
# Processing Record 4 of Set 11 | menongue
# Processing Record 5 of Set 11 | guaratinga
# Processing Record 6 of Set 11 | kimberley
# Processing Record 7 of Set 11 | paragominas
# Processing Record 8 of Set 11 | catamarca
# Processing Record 9 of Set 11 | oussouye
# Processing Record 10 of Set 11 | makinsk
# Processing Record 11 of Set 11 | dakar
# Processing Record 12 of Set 11 | hlinsko
# Processing Record 13 of Set 11 | myitkyina
# Processing Record 14 of Set 11 | kenosha
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | aksu
# Processing Record 17 of Set 11 | kathmandu
# Processing Record 18 of Set 11 | bhuj
# Processing Record 19 of Set 11 | ketchenery
# 'coord'
# Processing Record 20 of Set 11 | novoagansk
# Processing Record 21 of Set 11 | mabaruma
# Processing Record 22 of Set 11 | bosaso
# Processing Record 23 of Set 11 | lowestoft
# Processing Record 24 of Set 11 | beyneu
# Processing Record 25 of Set 11 | hofn
# Processing Record 26 of Set 11 | keetmanshoop
# Processing Record 27 of Set 11 | holzkirchen
# Processing Record 28 of Set 11 | nandaime
# Processing Record 29 of Set 11 | joshimath
# Processing Record 30 of Set 11 | mont-de-marsan
# Processing Record 31 of Set 11 | shablykino
# Processing Record 32 of Set 11 | grand gaube
# Processing Record 33 of Set 11 | beloha
# Processing Record 34 of Set 11 | kalengwa
# Processing Record 35 of Set 11 | angoche
# Processing Record 36 of Set 11 | laredo
# Processing Record 37 of Set 11 | turtkul
# 'coord'
# Processing Record 38 of Set 11 | chinsali
# Processing Record 39 of Set 11 | yenagoa
# Processing Record 40 of Set 11 | gonbad-e qabus
# Processing Record 41 of Set 11 | kathu
# Processing Record 42 of Set 11 | nantucket
# Processing Record 43 of Set 11 | saraland
# Processing Record 44 of Set 11 | vredendal
# Processing Record 45 of Set 11 | nortelandia
# Processing Record 46 of Set 11 | saint-leu
# Processing Record 47 of Set 11 | lasa
# Processing Record 48 of Set 11 | lydenburg
# Processing Record 49 of Set 11 | ozimek
# Processing Record 50 of Set 11 | meulaboh
# Processing Record 1 of Set 12 | abapo
# Processing Record 2 of Set 12 | bondoukou
# Processing Record 3 of Set 12 | molochnoye
# Processing Record 4 of Set 12 | canton
# Processing Record 5 of Set 12 | talara
# Processing Record 6 of Set 12 | tara
# Processing Record 7 of Set 12 | moshupa
# Processing Record 8 of Set 12 | georgiyevka
# Processing Record 9 of Set 12 | inirida
# Processing Record 10 of Set 12 | newala
# Processing Record 11 of Set 12 | wahran
# 'coord'
# Processing Record 12 of Set 12 | jamame
# Processing Record 13 of Set 12 | inhambane
# Processing Record 14 of Set 12 | la asuncion
# Processing Record 15 of Set 12 | vicosa
# Processing Record 16 of Set 12 | saint-paul
# Processing Record 17 of Set 12 | yuksekova
# Processing Record 18 of Set 12 | huambo
# Processing Record 19 of Set 12 | manadhoo
# Processing Record 20 of Set 12 | goycay
# 'coord'
# Processing Record 21 of Set 12 | malwan
# 'coord'
# Processing Record 22 of Set 12 | syracuse
# Processing Record 23 of Set 12 | dera din panah
# 'coord'
# Processing Record 24 of Set 12 | maldonado
# Processing Record 25 of Set 12 | bayir
# Processing Record 26 of Set 12 | san luis
# Processing Record 27 of Set 12 | fredericton
# Processing Record 28 of Set 12 | formoso do araguaia
# 'coord'
# Processing Record 29 of Set 12 | ivankiv
# Processing Record 30 of Set 12 | mamlyutka
# Processing Record 31 of Set 12 | osorio
# Processing Record 32 of Set 12 | odweyne
# Processing Record 33 of Set 12 | chanasma
# Processing Record 34 of Set 12 | elizabeth city
# Processing Record 35 of Set 12 | sorvag
# 'coord'
# Processing Record 36 of Set 12 | taunggyi
# Processing Record 37 of Set 12 | barbar
# 'coord'
# Processing Record 38 of Set 12 | burlington
# Processing Record 39 of Set 12 | yalchiki
# 'coord'
# Processing Record 40 of Set 12 | pathein
# Processing Record 41 of Set 12 | skagastrond
# 'coord'
# Processing Record 42 of Set 12 | nova soure
# Processing Record 43 of Set 12 | acari
# Processing Record 44 of Set 12 | clarence town
# Processing Record 45 of Set 12 | nalut
# Processing Record 46 of Set 12 | burla
# Processing Record 47 of Set 12 | dunajska streda
# Processing Record 48 of Set 12 | bonavista
# Processing Record 49 of Set 12 | rovaniemi
# Processing Record 50 of Set 12 | goderich
# Processing Record 1 of Set 13 | krasnoyarskiy
# Processing Record 2 of Set 13 | bonthe
# Processing Record 3 of Set 13 | lerwick
# Processing Record 4 of Set 13 | pozo colorado
# Processing Record 5 of Set 13 | xining
# Processing Record 6 of Set 13 | mao
# Processing Record 7 of Set 13 | nieuw amsterdam
# Processing Record 8 of Set 13 | romny
# Processing Record 9 of Set 13 | coihueco
# Processing Record 10 of Set 13 | matadi
# Processing Record 11 of Set 13 | vallenar
# Processing Record 12 of Set 13 | dawei
# Processing Record 13 of Set 13 | suez
# Processing Record 14 of Set 13 | strezhevoy
# Processing Record 15 of Set 13 | vetlanda
# Processing Record 16 of Set 13 | umm kaddadah
# Processing Record 17 of Set 13 | lokoja
# Processing Record 18 of Set 13 | geraldton
# Processing Record 19 of Set 13 | richards bay
# Processing Record 20 of Set 13 | carballo
# Processing Record 21 of Set 13 | amapa
# Processing Record 22 of Set 13 | sitio novo do tocantins
# Processing Record 23 of Set 13 | umm durman
# 'coord'
# Processing Record 24 of Set 13 | abakaliki
# Processing Record 25 of Set 13 | paso de los toros
# Processing Record 26 of Set 13 | jacareacanga
# Processing Record 27 of Set 13 | upington
# Processing Record 28 of Set 13 | salinopolis
# Processing Record 29 of Set 13 | oranjestad
# Processing Record 30 of Set 13 | sakakah
# Processing Record 31 of Set 13 | mormugao
# Processing Record 32 of Set 13 | itapua poty
# 'coord'
# Processing Record 33 of Set 13 | riyadh
# Processing Record 34 of Set 13 | saint-francois
# Processing Record 35 of Set 13 | nadvoitsy
# Processing Record 36 of Set 13 | mae hong son
# Processing Record 37 of Set 13 | vapi
# Processing Record 38 of Set 13 | quatre cocos
# Processing Record 39 of Set 13 | husavik
# Processing Record 40 of Set 13 | guaimaro
# Processing Record 41 of Set 13 | karlskrona
# Processing Record 42 of Set 13 | banes
# Processing Record 43 of Set 13 | souris
# Processing Record 44 of Set 13 | kikwit
# Processing Record 45 of Set 13 | scottsburgh
# 'coord'
# Processing Record 46 of Set 13 | baherden
# Processing Record 47 of Set 13 | josanicka banja
# Processing Record 48 of Set 13 | tasgaon
# Processing Record 49 of Set 13 | pavagada
# Processing Record 50 of Set 13 | kaputa
# Processing Record 1 of Set 14 | bojnurd
# Processing Record 2 of Set 14 | panapakkam
# 'coord'
# Processing Record 3 of Set 14 | mitu
# Processing Record 4 of Set 14 | malakal
# Processing Record 5 of Set 14 | gobabis
# Processing Record 6 of Set 14 | ayia galini
# Processing Record 7 of Set 14 | karpenision
# 'coord'
# Processing Record 8 of Set 14 | russkaya polyana
# Processing Record 9 of Set 14 | karakendzha
# 'coord'
# Processing Record 10 of Set 14 | diffa
# Processing Record 11 of Set 14 | nuoro
# Processing Record 12 of Set 14 | toliary
# 'coord'
# Processing Record 13 of Set 14 | oktyabrskiy
# Processing Record 14 of Set 14 | tutoia
# Processing Record 15 of Set 14 | obigarm
# Processing Record 16 of Set 14 | nokaneng
# Processing Record 17 of Set 14 | adiake
# Processing Record 18 of Set 14 | buritis
# Processing Record 19 of Set 14 | kortkeros
# Processing Record 20 of Set 14 | scarborough
# Processing Record 21 of Set 14 | mrirt
# 'coord'
# Processing Record 22 of Set 14 | mogadishu
# Processing Record 23 of Set 14 | turmalina
# Processing Record 24 of Set 14 | piacabucu
# Processing Record 25 of Set 14 | basar
# Processing Record 26 of Set 14 | ilabaya
# Processing Record 27 of Set 14 | agirish
# Processing Record 28 of Set 14 | haukipudas
# Processing Record 29 of Set 14 | kidal
# Processing Record 30 of Set 14 | orikum
# Processing Record 31 of Set 14 | aktau
# Processing Record 32 of Set 14 | pangody
# Processing Record 33 of Set 14 | gryazovets
# Processing Record 34 of Set 14 | rawson
# Processing Record 35 of Set 14 | pasighat
# Processing Record 36 of Set 14 | bam
# Processing Record 37 of Set 14 | longonjo
# Processing Record 38 of Set 14 | ayolas
# Processing Record 39 of Set 14 | nicoya
# Processing Record 40 of Set 14 | mezen
# Processing Record 41 of Set 14 | nanyamba
# Processing Record 42 of Set 14 | tahoua
# Processing Record 43 of Set 14 | loiza
# Processing Record 44 of Set 14 | kamenka
# Processing Record 45 of Set 14 | luziania
# Processing Record 46 of Set 14 | palabuhanratu
# 'coord'
# Processing Record 47 of Set 14 | awjilah
# Processing Record 48 of Set 14 | bur gabo
# 'coord'
# Processing Record 49 of Set 14 | ludwigslust
# Processing Record 50 of Set 14 | cheuskiny
# 'coord'
# Processing Record 1 of Set 15 | kenda
# Processing Record 2 of Set 15 | dasoguz
# Processing Record 3 of Set 15 | maridi
# Processing Record 4 of Set 15 | rio grande
# Processing Record 5 of Set 15 | sorland
# Processing Record 6 of Set 15 | olinda
# Processing Record 7 of Set 15 | garowe
# Processing Record 8 of Set 15 | balykshi
# Processing Record 9 of Set 15 | vangaindrano
# Processing Record 10 of Set 15 | manoel urbano
# Processing Record 11 of Set 15 | abu kamal
# Processing Record 12 of Set 15 | voyvozh
# Processing Record 13 of Set 15 | antofagasta
# Processing Record 14 of Set 15 | koumra
# Processing Record 15 of Set 15 | bhag
# Processing Record 16 of Set 15 | musselburgh
# Processing Record 17 of Set 15 | derzhavinsk
# Processing Record 18 of Set 15 | ulvik
# Processing Record 19 of Set 15 | ruwi
# Processing Record 20 of Set 15 | yumen
# Processing Record 21 of Set 15 | yaviza
# Processing Record 22 of Set 15 | gravdal
# Processing Record 23 of Set 15 | machachi
# Processing Record 24 of Set 15 | bhadohi
# Processing Record 25 of Set 15 | roros
# Processing Record 26 of Set 15 | tabas
# Processing Record 27 of Set 15 | abong mbang
# Processing Record 28 of Set 15 | roald
# Processing Record 29 of Set 15 | teya
# Processing Record 30 of Set 15 | quimperle
# Processing Record 31 of Set 15 | storforshei
# Processing Record 32 of Set 15 | novoseleznevo
# Processing Record 33 of Set 15 | kaliua
# Processing Record 34 of Set 15 | mandera
# Processing Record 35 of Set 15 | timmins
# Processing Record 36 of Set 15 | saryshagan
# 'coord'
# Processing Record 37 of Set 15 | dvinskoy
# Processing Record 38 of Set 15 | bushehr
# Processing Record 39 of Set 15 | sargur
# Processing Record 40 of Set 15 | azimur
# 'coord'
# Processing Record 41 of Set 15 | mitsamiouli
# Processing Record 42 of Set 15 | karasjok
# Processing Record 43 of Set 15 | san rafael del sur
# Processing Record 44 of Set 15 | potgietersrus
# 'coord'
# Processing Record 45 of Set 15 | asyut
# Processing Record 46 of Set 15 | oulainen
# Processing Record 47 of Set 15 | ushtobe
# Processing Record 48 of Set 15 | ihosy
# Processing Record 49 of Set 15 | jarjis
# 'coord'
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Velventos  40.2517   22.0631     51.80        43          87
# 1             Mahebourg -20.4081   57.7000     78.80        83          40
# 2             Carnarvon -24.8667  113.6333     77.00       100           7
# 3                Sibiti  -3.6819   13.3499     70.25       100         100
# 4              Hermanus -34.4187   19.2345     57.99        88           4
# ..                  ...      ...       ...       ...       ...         ...
# 682  San Rafael Del Sur  11.8485  -86.4384     89.60        43          20
# 683               Asyut  27.1810   31.1837     55.40        71           0
# 684            Oulainen  64.2667   24.8000     18.00        89          21
# 685             Ushtobe  45.2514   77.9838     32.81        92         100
# 686               Ihosy -22.4000   46.1167     68.63        90         100
#
#      Wind Speed Country                 Date
# 0          2.30      GR  2021-02-07 23:55:39
# 1          5.75      MU  2021-02-07 23:55:39
# 2          8.05      AU  2021-02-07 23:55:39
# 3          2.98      CG  2021-02-07 23:55:40
# 4          1.59      ZA  2021-02-07 23:52:50
# ..          ...     ...                  ...
# 682       11.50      NI  2021-02-07 23:57:07
# 683        5.75      EG  2021-02-07 23:57:08
# 684        4.00      FI  2021-02-07 23:57:08
# 685        5.95      KZ  2021-02-07 23:57:08
# 686        1.70      MG  2021-02-07 23:57:08
#
# [687 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
City_data_df2 = city_data_df[new_column_order]
City_data_df2.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Velventos      GR  40.2517   22.0631     51.80        43          87
# 1     Mahebourg      MU -20.4081   57.7000     78.80        83          40
# 2     Carnarvon      AU -24.8667  113.6333     77.00       100           7
# 3        Sibiti      CG  -3.6819   13.3499     70.25       100         100
# 4      Hermanus      ZA -34.4187   19.2345     57.99        88           4
# 5  Ponta Do Sol      PT  32.6667  -17.1000     57.99        75          42
# 6     Cape Town      ZA -33.9258   18.4232     66.20        68           0
# 7     Busselton      AU -33.6500  115.3333     64.00        99          81
# 8     Vestmanna      FO  62.1564   -7.1664     35.60        60          75
# 9   East London      ZA -33.0153   27.9116     71.46        82          95
#
#    Wind Speed
# 0        2.30
# 1        5.75
# 2        8.05
# 3        2.98
# 4        1.59
# 5        4.00
# 6       14.97
# 7        1.99
# 8       18.41
# 9        9.73

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
City_data_df2.to_csv(output_data_file, index_label="City_ID")
